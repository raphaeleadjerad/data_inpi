# %%
# import des tables pm et rep
import os
import s3fs
import pandas as pd
# Create filesystem object
S3_ENDPOINT_URL = "https://" + os.environ["AWS_S3_ENDPOINT"]
fs = s3fs.S3FileSystem(client_kwargs={'endpoint_url': S3_ENDPOINT_URL})
BUCKET = "radjerad/inpi"
FILE_KEY_S3 = "data_rep_2017.csv"
FILE_PATH_S3 = BUCKET + "/" + FILE_KEY_S3

with fs.open(FILE_PATH_S3, mode="rb") as file_in:
    df_rep = pd.read_csv(file_in, sep=";")
# Out:
# /tmp/ipykernel_706/2301143330.py:13: DtypeWarning: Columns (7,14,15,17,26,32,33,34,35,36,37,38,39,40,42) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_rep = pd.read_csv(file_in, sep=";")

# %%
df_rep.shape # 9 504 907
# Out:
# (9504907, 48)

# %%
df_rep.head()
# Out:
#    Code Greffe Nom_Greffe Numero_Gestion      Siren        Type  \
# 0         5802     Nevers     2000B00416  429628324  P.Physique
# 1         5802     Nevers     2003B00185  450548748  P.Physique
# 2         5802     Nevers     2003B00185  450548748   P. Morale
# 3         5802     Nevers     2003B00185  450548748   P. Morale
# 4         5802     Nevers     2017B00123  829334234  P.Physique
#
#   Nom_Patronymique Nom_Usage Pseudonyme                  Prénoms  \
# 0        CHARPENET   ROUSSET        NaN  Madeleine Marie-Thérèse
# 1            MOREL       NaN        NaN                   Xavier
# 2              NaN       NaN        NaN                      NaN
# 3              NaN       NaN        NaN                      NaN
# 4           REBOUR       NaN        NaN       Rebecca, Angélique
#
#             Dénomination  ...  Rep_Perm_Pays Conjoint_Collab_Nom_Patronym  \
# 0                    NaN  ...            NaN                          NaN
# ...

# %%
FILE_KEY_S3 = "data_pm_2017.csv"
FILE_PATH_S3 = BUCKET + "/" + FILE_KEY_S3

with fs.open(FILE_PATH_S3, mode="rb") as file_in:
    df_pm = pd.read_csv(file_in, sep=";")
# Out:
# /tmp/ipykernel_706/3002956283.py:5: DtypeWarning: Columns (8,10,11,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_pm = pd.read_csv(file_in, sep=";")

# %%
df_pm.shape # 4 296 552
# Out:
# (4296552, 29)

# %%
df_pm.head()
# Out:
#    Code Greffe Nom_Greffe Numero_Gestion      Siren Type_Inscription  \
# 0         5802     Nevers     2000B00416  429628324                P
# 1         5802     Nevers     2003B00185  450548748                P
# 2         5802     Nevers     2017B00123  829334234                P
# 3         5802     Nevers     2017D00065  828733352                P
# 4         5802     Nevers     2016B00313  823697826                P
#
#   Date_Immatriculation Date_1re_Immatriculation  Date_Radiation  \
# 0           2000-03-02                      NaN             NaN
# 1           2003-10-22                      NaN             NaN
# 2           2017-05-03               2017-05-03             NaN
# 3           2017-03-31               2017-03-31             NaN
# 4           2016-11-15               2016-11-15             NaN
#
#   Date_Transfert Sans_Activité  ...   Capital Capital_Actuel Devise  \
# 0            NaN           NaN  ...   86000.0            NaN  Euros
# ...

# %%
df_rep["Siren"].head()
# Out:
# 0    429628324
# 1    450548748
# 2    450548748
# 3    450548748
# 4    829334234
# Name: Siren, dtype: int64

# %%
df_pm["Siren"].head()
# Out:
# 0    429628324
# 1    450548748
# 2    829334234
# 3    828733352
# 4    823697826
# Name: Siren, dtype: int64

# %%
societes_rep_tc = pd.merge(df_pm, df_rep, on=["Siren"], how="left")

# %%
societes_rep_tc.shape # 10 526 915
# Out:
# (10526915, 76)
